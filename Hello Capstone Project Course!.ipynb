# %% [markdown]
# # Hello Capstone Project Course!

# %% [markdown]
# #### This notebook is part of the first assignment of Coursera-Capstone Project Course. This is an introductory exercise to get familiarized with uploading files to GitHub repository.

# %% [markdown]
# 1. Importing Pandas and Numpy Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 2. Print the statement, 'Hello Capstone Project Course!'

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %% [markdown]
# That's all for this introductory assignment!
